# %%
import numpy as np

# %% [markdown]
# # Map et reduce
#
# Les Framework comme Spark sont basés sur les concepts de Map et Reduce. Il s'agit simplement de fonctions de traitement de données.
#
# ## Map
#
# Map prend en argument une fonction et une collection et retourne une collection. La fonction étant apliqué sur chaque élément de la collection. Executer le code ci-dessous et expliquer ce qu'il fait. Vous rappelez vous de ce qu'est une fonction anonyme?

# %%
a = [1, 2, 4, 5, 6]
b = map(lambda x: 2 * x, a)

for i in b:
    print(i)
# Out:
# 2
# 4
# 8
# 10
# 12

# %% [markdown]
# Créer une liste de nombres entiers aléatoires contenant 1000 exemples.
# A l'aide de la fonction map, retourner une collection qui contient True si le nombre était pair, et False sinon.

# %%
c = np.random.randint(1,1000,1000)
    
d = map(lambda x: True if x % 2 == 0, else False, c)

for i in d:
    print(i)
# Out:
# True
# True
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# True
# True
# False
# False
# False
# True
# False
# False
# False
# True
# True
# False
# False
# True
# False
# True
# True
# True
# False
# True
# False
# False
# False
# False
# True
# True
# False
# False
# True
# False
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True
# False
# True
# True
# True
# False
# True
# True
# False
# False
# False
# False
# True
# False
# False
# False
# False
# True
# False
# True
# False
# True
# False
# True
# False
# False
# False
# False
# False
# True
# False
# False
# True
# True
# True
# True
# False
# True
# False
# False
# False
# True
# True
# False
# False
# False
# False
# False
# False
# False
# True
# False
# False
# True
# False
# True
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False
# True
# True
# True
# True
# True
# True
# True
# True
# True
# ...

# %% [markdown]
# La seule différence entre le map de python et le map de spark, c'est que le map de ce dernier découpe le calcul sur plusieurs machinec pour paralléliser le traitement.

# %% [markdown]
# ## Reduce
#
# La fonction reduce prend en entrée une collection et retourne une reduction de celle ci. Par exemple, elle permet de faire la somme des éléments d'une liste.
# Executer le code suivant.

# %%
from functools import reduce

acc_init = 0
a = [1, 2, 3, 5] 

out = reduce(lambda e, acc: e + acc, a, acc_init)
out
# Out:
# 11

# %% [markdown]
# De la même manière, la seule différence entre le reduce de python et celui de spark, c'est que celui de spark découpe en plusieurs morceaux et parallélise le traitement.

# %% [markdown]
# On considère le big dataset suivant :

# %%
a = ["ceci n'est pas du big data", 'bonjour voila du texte', "mangez donc un croissant", 'vivement la pause']

# %% [markdown]
# A l'aide de la fonction map, découper chaque phrase en en mots. On aura donc une liste de listes.

# %%
b = map(lambda x: x.split(), a)

for i in b:
    print(i)
# Out:
# ['ceci', "n'est", 'pas', 'du', 'big', 'data']
# ['bonjour', 'voila', 'du', 'texte']
# ['mangez', 'donc', 'un', 'croissant']
# ['vivement', 'la', 'pause']

# %% [markdown]
# A l'aide de map et reduce. Renvoyer le nombre total de mots dans a.

# %%
c = map(lambda x: len(x.split(" ")), a)
for i in c:
    print(i)
# Out:
# 6
# 4
# 4
# 3

# %%
d = reduce((lambda x,y: x+y), (map(lambda x: len(x.split(" ")), a)))
d
# Out:
# 17
